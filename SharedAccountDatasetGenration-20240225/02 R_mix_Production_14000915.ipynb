 {16, 30},
 {47, 438},
 {45, 207},
 {311, 625},
 {288, 480},
 {294, 450},
 {73, 470},
 {121, 163},
 {395, 538},
 {244, 314},
 {80, 168},
 {181, 488},
 {71, 111},
 {727, 927},
 {2, 66},
 {182, 265},
 {139, 693},
 {74, 774},
 {36, 39},
 {125, 775},
 {28, 44},
 {351, 686},
 {178, 405},
 {8, 35},
 {357, 533},
 {518, 773},
 {4, 32},
 {810, 902},
 {149, 597},
 {69, 674},
 {96, 350},
 {337, 563},
 {136, 277},
 {170, 247},
 {100, 172},
 {308, 373},
 {41, 46},
 {186, 202},
 {650, 884},
 {160, 800},
 {104, 370},
 {37, 515},
 {699, 732},
 {86, 608},
 {352, 369},
 {24, 33},
 {152, 517},
 {382, 778},
 {161, 719},
 {280, 526},
 {85, 147},
 {229, 840},
 {191, 911},
 {442, 916},
 {70, 334},
 {20, 570},
 {43, 684},
 {316, 360},
 {76, 383},
 {75, 241},
 {68, 468},
 {132, 411},
 {780, 821},
 {27, 865},
 {128, 266},
 {110, 255},
 {737, 823},
 {59, 361},
 {365, 422},
 {88, 257},
 {120, 569}]

# %%
sa3 = [{123, 205, 589},
 {113, 472, 701},
 {146, 299, 325},
 {77, 179, 251},
 {7, 49, 913}]

# %%
sa4 = [{95, 272, 340, 717}]

# %% [markdown]
# ###  shared account production

# %%
sa4_newrow = np.zeros((len(sa4),n),dtype=float)
for item in sa4:
    for element in item:
        sa4_newrow[0] = sa4_newrow[0] + R.iloc[element,:]

# %%
# ردیف حساب کاربری مشترک 3 کاربره رو بساز
sa3_newrow = np.zeros((len(sa3),n),dtype=float)
i = 0
for item in sa3:
    for element in item:
        sa3_newrow[i] = sa3_newrow[i] + R.iloc[element,:]
    i = i +1

# %%
# ردیف حساب کاربری مشترک 2 کاربره رو بساز
sa2_newrow = np.zeros((len(sa2),n),dtype=float)
i = 0
for item in sa2:
    for element in item:
        sa2_newrow[i] = sa2_newrow[i] + R.iloc[element,:]
    i = i +1

# %% [markdown]
# # R_mix Production

# %%
m_mix = len(sa1)+len(sa2)+len(sa3)+len(sa4)
all_rows = {i for i in range(m_mix)}
used_rows = set()
available_rows = all_rows - used_rows

# %%
places = [i for i in range(m_mix)]
np.random.seed(1337)
random_places_in_R_mix = []
for i in range(m_mix):
    j = np.random.randint(0,len(places))
    random_places_in_R_mix.append(places[j])
    places.pop(j)

# %%
R_mix = np.zeros((m_mix,n),dtype=float)
i=0
j=0
l = m
save_list = []

for counter in range(len(sa1)):
    R_mix[random_places_in_R_mix[i]]=R.iloc[list(sa1)[j],:]
    save_list.append((random_places_in_R_mix[i],{list(sa1)[j]}))
    i = i+1
    j = j+1
    l = l-1

j=0
for counter in range(len(sa2)):
    R_mix[random_places_in_R_mix[i]]=R.iloc[list(sa2[j])[0],:]+R.iloc[list(sa2[j])[1],:]
    save_list.append((random_places_in_R_mix[i],sa2[j]))
    i = i+1
    j = j+1
    l = l-2

j=0    
for counter in range(len(sa3)):
    R_mix[random_places_in_R_mix[i]]=R.iloc[list(sa3[j])[0],:]+R.iloc[list(sa3[j])[1],:]+R.iloc[list(sa3[j])[2],:]
    save_list.append((random_places_in_R_mix[i],sa3[j]))
    i = i+1
    j = j+1
    l = l-3

j=0    
for counter in range(len(sa4)):
    R_mix[random_places_in_R_mix[i]]=R.iloc[list(sa4[j])[0],:]+R.iloc[list(sa4[j])[1],:]+R.iloc[list(sa4[j])[2],:] +R.iloc[list(sa4[j])[3],:]
    save_list.append((random_places_in_R_mix[i],sa3[j]))
    i = i+1
    j = j+1
    l = l-4
print(l)
print('if it is zero means that we allocate all users of movielens')
# Out:
# 0
# if it is zero means that we allocate all users of movielens

# %%
pd.DataFrame(R_mix).to_csv('R_mix.csv')

# %%
random_places_in_R_mix
# Out:
# [151,
#  190,
#  234,
#  168,
#  477,
#  684,
#  350,
#  82,
#  85,
#  72,
#  272,
#  399,
#  448,
#  355,
#  23,
#  678,
#  133,
#  97,
#  22,
#  384,
#  635,
#  213,
#  62,
#  750,
#  681,
#  775,
#  352,
#  624,
#  455,
#  206,
#  424,
#  544,
#  609,
#  598,
#  610,
#  664,
#  682,
#  743,
#  772,
#  347,
#  208,
#  391,
#  528,
#  559,
#  748,
#  652,
#  715,
#  451,
#  754,
#  550,
#  353,
#  139,
#  644,
#  694,
#  320,
#  201,
#  556,
#  530,
#  99,
#  358,
#  80,
#  322,
#  475,
#  537,
#  731,
#  464,
#  51,
#  78,
#  93,
#  558,
#  326,
#  472,
#  557,
#  220,
#  65,
#  301,
#  698,
#  515,
#  607,
#  121,
#  769,
#  69,
#  586,
#  554,
#  236,
#  722,
#  129,
#  107,
#  704,
#  379,
#  728,
#  734,
#  266,
#  440,
#  717,
#  489,
#  423,
#  449,
#  390,
#  465,
#  703,
#  299,
#  564,
#  755,
#  0,
#  522,
#  8,
#  497,
#  365,
#  332,
#  276,
#  286,
#  549,
#  452,
#  9,
#  330,
#  281,
#  454,
#  711,
#  13,
#  226,
#  518,
#  462,
#  392,
#  183,
#  604,
#  196,
# ...

# %%
save_list
# Out:
# [(151, {0}),
#  (190, {5}),
#  (234, {6}),
#  (168, {9}),
#  (477, {10}),
#  (684, {11}),
#  (350, {12}),
#  (82, {15}),
#  (85, {23}),
#  (72, {25}),
#  (272, {42}),
#  (399, {48}),
#  (448, {55}),
#  (355, {57}),
#  (23, {58}),
#  (678, {61}),
#  (133, {62}),
#  (97, {63}),
#  (22, {65}),
#  (384, {72}),
#  (635, {78}),
#  (213, {81}),
#  (62, {82}),
#  (750, {84}),
#  (681, {89}),
#  (775, {90}),
#  (352, {91}),
#  (624, {93}),
#  (455, {94}),
#  (206, {98}),
#  (424, {101}),
#  (544, {102}),
#  (609, {103}),
#  (598, {105}),
#  (610, {108}),
#  (664, {112}),
#  (682, {114}),
#  (743, {115}),
#  (772, {116}),
#  (347, {118}),
#  (208, {122}),
#  (391, {124}),
#  (528, {126}),
#  (559, {127}),
#  (748, {129}),
#  (652, {135}),
#  (715, {140}),
#  (451, {143}),
#  (754, {144}),
#  (550, {148}),
#  (353, {150}),
#  (139, {151}),
#  (644, {153}),
#  (694, {157}),
#  (320, {158}),
#  (201, {159}),
#  (556, {162}),
#  (530, {167}),
#  (99, {173}),
#  (358, {175}),
#  (80, {176}),
# ...

# %%
what_happend_df = pd.DataFrame(save_list,columns=['are in row','rows of'])

# %%
what_happend_df.to_csv('what_happend_in_SA_production2.csv')
